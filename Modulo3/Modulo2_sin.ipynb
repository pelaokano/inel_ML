# %% [markdown]
# <img src="logo_inel.png">

# %% [markdown]
# <h2 align="center">Machine Learning con Python</h2>
#
# <h3 align="center">Instructor: Adrián Alarcón B</h3>

# %% [markdown]
# # Modulo 2 - Introducción a Python para Ciencia de Datos y ML

# %% [markdown]
# ### 2.1 Lógica del valor de los datos para la toma de decisiones

# %% [markdown]
# La lógica detrás del valor de los datos para la toma de decisiones se basa en el hecho de que los datos pueden proporcionar información precisa y relevante que permite a las organizaciones tomar decisiones más informadas y acertadas. Los datos son la materia prima que permite obtener información, la cual a su vez permite a los gerentes y líderes empresariales identificar oportunidades y desafíos, detectar patrones y tendencias, y hacer predicciones.
#
# La lógica detrás del valor de los datos para la toma de decisiones radica en su capacidad para proporcionar información precisa, relevante y actualizada que permite a las empresas tomar decisiones más informadas y estratégicas, adaptarse a los cambios en el mercado y las tendencias del consumidor, mejorar la eficiencia y reducir costos.
# ChatGPT Mar 23 Version.

# %% [markdown]
# ### 2.2 Fundamentos estadísticos y 2.6 Conceptos de estadística para ML

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\56965\Documents\python\Inel_ML\clases\Modulo3\data\\titanic_train.csv', delimiter=",", encoding='latin-1')

# %%
#pd.read_csv
#pd.read_excel
#pd.read_json
#pd.read_html

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %% [markdown]
# #### Descripción campos dataset
#
# <ul>
# <li>survival - Survival (0 = No; 1 = Yes)</li>
# <li>class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)</li>
# <li>name - Name</li>
# <li>sex - Sex</li>
# <li>age - Age</li>
# <li>sibsp - Number of Siblings/Spouses Aboard</li>
# <li>parch - Number of Parents/Children Aboard</li>
# <li>ticket - Ticket Number</li>
# <li>fare - Passenger Fare</li>
# <li>cabin - Cabin</li>
# <li>embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)</li>
# <li>boat - Lifeboat (if survived)</li>
# <li>body - Body number (if did not survive and body was recovered)</li>
# </ul>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
np.int32
# Out:
# numpy.int32

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(subset=["Age","Cabin","Embarked"],inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Age']=df['Age'].astype(np.int32)

# %%
df.memory_usage()
# Out:
# Index          1464
# PassengerId    1464
# Survived       1464
# Pclass         1464
# Name           1464
# Sex            1464
# Age             732
# SibSp          1464
# Parch          1464
# Ticket         1464
# Fare           1464
# Cabin          1464
# Embarked       1464
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    int32
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 17.9+ KB

# %%
df['Survived']=df['Survived'].astype(np.int32)

# %%
df.memory_usage()
# Out:
# Index          1464
# PassengerId    1464
# Survived        732
# Pclass         1464
# Name           1464
# Sex            1464
# Age             732
# SibSp          1464
# Parch          1464
# Ticket         1464
# Fare           1464
# Cabin          1464
# Embarked       1464
# dtype: int64

# %%
df["Name"].unique()
# Out:
# array(['Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'McCarthy, Mr. Timothy J', 'Sandstrom, Miss. Marguerite Rut',
#        'Bonnell, Miss. Elizabeth', 'Beesley, Mr. Lawrence',
#        'Sloper, Mr. William Thompson', 'Fortune, Mr. Charles Alexander',
#        'Harper, Mrs. Henry Sleeper (Myna Haxtun)',
#        'Ostby, Mr. Engelhart Cornelius', 'Harris, Mr. Henry Birkhardt',
#        'Nye, Mrs. (Elizabeth Ramell)', 'Moen, Mr. Sigurd Hansen',
#        'Fortune, Miss. Mabel Helen', 'Chaffee, Mr. Herbert Fuller',
#        'Goldschmidt, Mr. George B', 'Greenfield, Mr. William Bertram',
#        'White, Mr. Richard Frasar', 'Porter, Mr. Walter Chamberlain',
#        'Baxter, Mr. Quigg Edmond', 'Webber, Miss. Susan',
#        'White, Mr. Percival Wayland', 'Newsom, Miss. Helen Monypeny',
#        'Futrelle, Mr. Jacques Heath', 'Giglio, Mr. Victor',
#        'Navratil, Mr. Michel ("Louis M Hoffman")',
#        'Pears, Mrs. Thomas (Edith Wearne)', 'Van der hoef, Mr. Wyckoff',
#        'Smith, Mr. James Clinch', 'Isham, Miss. Ann Elizabeth',
#        'Becker, Master. Richard F', 'Navratil, Master. Michel M',
#        'Brown, Mrs. James Joseph (Margaret Tobin)',
#        'Lurette, Miss. Elise', 'Strom, Miss. Telma Matilda',
#        'Blank, Mr. Henry', 'Newell, Miss. Madeleine',
#        'Bazzani, Miss. Albina', 'Hoyt, Mr. Frederick Maxfield',
#        'Harris, Mrs. Henry Birkhardt (Irene Wallach)',
#        'Minahan, Dr. William Edward', 'Beckwith, Mr. Richard Leonard',
#        'Strom, Mrs. Wilhelm (Elna Matilda Persson)',
#        'Stead, Mr. William Thomas', 'Cherry, Miss. Gladys',
#        'Taussig, Mr. Emil', 'Harrison, Mr. William',
#        'Graham, Mrs. William Thompson (Edith Junkins)',
#        'Bissette, Miss. Amelia', 'Natsch, Mr. Charles H',
#        'Andrews, Miss. Kornelia Theodosia',
#        'Bishop, Mrs. Dickinson H (Helen Walton)',
#        'Levy, Mr. Rene Jacques', 'Allison, Miss. Helen Loraine',
#        'Baxter, Mrs. James (Helene DeLaudeniere Chaput)',
#        'Allison, Master. Hudson Trevor',
#        'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)',
#        'Francatelli, Miss. Laura Mabel', 'Hays, Miss. Margaret Bechstein',
#        'Ryerson, Miss. Emily Borie', 'Wick, Miss. Mary Natalie',
#        'Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)',
#        'Young, Miss. Marie Grice', 'Ball, Mrs. (Ada E Hall)',
#        'Hippach, Miss. Jean Gertrude', 'Partner, Mr. Austen',
#        'Graham, Mr. George Edward', 'Pears, Mr. Thomas Clinton',
#        'Burns, Miss. Elizabeth Margaret', 'Blackwell, Mr. Stephen Weart',
#        'Navratil, Master. Edmond Roger', 'Fortune, Miss. Alice Elizabeth',
#        'Brown, Miss. Amelia "Mildred"', 'Bowerman, Miss. Elsie Edith',
#        'Warren, Mrs. Frank Manley (Anna Sophia Atkinson)',
#        'Aubart, Mme. Leontine Pauline', 'Harder, Mr. George Achilles',
#        'Widener, Mr. Harry Elkins', 'Carter, Mr. William Ernest',
#        'Newell, Miss. Marjorie',
#        'Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)',
#        'Minahan, Miss. Daisy E', 'Pickard, Mr. Berk (Berk Trembisky)',
#        'Bjornstrom-Steffansson, Mr. Mauritz Hakan',
#        'Silvey, Mr. William Baird', 'Carter, Miss. Lucile Polk',
#        'Fortune, Mr. Mark', 'Dodge, Master. Washington',
#        'Peuchen, Major. Arthur Godfrey',
#        'Foreman, Mr. Benjamin Laventall', 'Goldenberg, Mr. Samuel L',
#        'Millet, Mr. Francis Davis', 'Anderson, Mr. Harry',
#        'Gee, Mr. Arthur H',
#        'Jerwan, Mrs. Amin S (Marie Marthe Thuillard)',
#        'Bishop, Mr. Dickinson H',
#        'Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)',
#        'Kent, Mr. Edward Austin', 'Molson, Mr. Harry Markland',
#        'Eustis, Miss. Elizabeth Mussey',
#        'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#        'Maioni, Miss. Roberta',
#        'Penasco y Castellana, Mr. Victor de Satode',
#        'McGough, Mr. James Robert', 'Walker, Mr. William Anderson',
#        'Lemore, Mrs. (Amelia Milley)', 'Perreault, Miss. Anne',
#        'Hippach, Mrs. Louis Albert (Ida Sophia Fischer)',
#        'Butt, Major. Archibald Willingham',
#        'Frolicher, Miss. Hedwig Margaritha', 'Crosby, Miss. Harriet R',
#        'Douglas, Mr. Walter Donald', 'Thayer, Mr. John Borland Jr',
#        'Duff Gordon, Lady. (Lucille Christiana Sutherland) ("Mrs Morgan")',
#        'Taussig, Mrs. Emil (Tillie Mandelbaum)',
#        'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#        'Flynn, Mr. John Irwin ("Irving")',
#        'Silvey, Mrs. William Baird (Alice Munger)',
#        'Thayer, Mrs. John Borland (Marian Longstreth Morris)',
#        'Ross, Mr. John Hugo', 'Taussig, Miss. Ruth',
#        'Frolicher-Stehli, Mr. Maxmillian',
#        'Stephenson, Mrs. Walter Bertram (Martha Eustis)',
#        'Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")',
#        'Shutes, Miss. Elizabeth W', 'Becker, Miss. Marion Louise',
#        'Kimball, Mr. Edwin Nelson Jr', 'Sutton, Mr. Frederick',
#        'Longley, Miss. Gretchen Fiske',
#        'Barkworth, Mr. Algernon Henry Wilson',
#        'Stahelin-Maeglin, Dr. Max', 'Sagesser, Mlle. Emma',
#        'Harper, Mr. Henry Sleeper', 'Simonius-Blumer, Col. Oberst Alfons',
#        'Newell, Mr. Arthur Webster', 'Colley, Mr. Edward Pomeroy',
#        'Davidson, Mr. Thornton', 'Cardeza, Mr. Thomas Drake Martinez',
#        'Hassab, Mr. Hammad', 'Madill, Miss. Georgette Alexandra',
#        'Dick, Mr. Albert Adrian', 'Thayer, Mr. John Borland',
#        'Humblen, Mr. Adolf Mathias Nicolai Olsen',
#        'Astor, Mrs. John Jacob (Madeleine Talmadge Force)',
#        'Silverthorne, Mr. Spencer Victor',
#        'Calderhead, Mr. Edward Pennington',
#        'Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")',
#        'Taylor, Mr. Elmer Zebley',
#        'Soholt, Mr. Peter Andreas Lauritz Andersen',
#        'Endres, Miss. Caroline Louise',
#        'Troutt, Miss. Edwina Celia "Winnie"',
#        'Chambers, Mr. Norman Campbell', 'Allen, Miss. Elisabeth Walton',
#        'Lesurer, Mr. Gustave J', 'Cavendish, Mr. Tyrell William',
#        'Ryerson, Miss. Susan Parker "Suzette"',
#        'Crosby, Capt. Edward Gifford', 'Marvin, Mr. Daniel Warner',
#        'Moor, Master. Meier',
#        'Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)',
#        'Carter, Mrs. William Ernest (Lucile Polk)',
#        'Hogeboom, Mrs. John C (Anna Andrews)', 'Mack, Mrs. (Mary)',
#        'Robert, Mrs. Edward Scott (Elisabeth Walton McMillan)',
#        'Dick, Mrs. Albert Adrian (Vera Gillespie)',
#        'Long, Mr. Milton Clyde', 'Guggenheim, Mr. Benjamin',
#        'Leader, Dr. Alice (Farnham)',
#        'Carter, Master. William Thornton II', 'Andrews, Mr. Thomas Jr',
#        'Chambers, Mrs. Norman Campbell (Bertha Griggs)',
#        'Hays, Mrs. Charles Melville (Clara Jennings Gregg)',
#        'Moor, Mrs. (Beila)', 'Compton, Miss. Sara Rebecca',
#        'Lines, Miss. Mary Conover', 'Daly, Mr. Peter Denis ',
#        'Swift, Mrs. Frederick Joel (Margaret Welles Barron)',
#        'Roebling, Mr. Washington Augustus II',
#        'Beckwith, Mrs. Richard Leonard (Sallie Monypeny)',
#        'Carlsson, Mr. Frans Olof',
#        'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#        'Graham, Miss. Margaret Edith', 'Behr, Mr. Karl Howell'],
#       dtype=object)

# %%
df[df["Age"]>=44][["Name","Age", "Embarked"]]
# Out:
#                                                   Name  Age Embarked
# 6                              McCarthy, Mr. Timothy J   54        S
# 11                            Bonnell, Miss. Elizabeth   58        S
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)   49        C
# 54                      Ostby, Mr. Engelhart Cornelius   65        C
# 62                         Harris, Mr. Henry Birkhardt   45        S
# 92                         Chaffee, Mr. Herbert Fuller   46        S
# 96                           Goldschmidt, Mr. George B   71        C
# 110                     Porter, Mr. Walter Chamberlain   47        S
# 124                        White, Mr. Percival Wayland   54        S
# 170                          Van der hoef, Mr. Wyckoff   61        S
# 174                            Smith, Mr. James Clinch   56        C
# 177                         Isham, Miss. Ann Elizabeth   50        C
# 194          Brown, Mrs. James Joseph (Margaret Tobin)   44        C
# 195                               Lurette, Miss. Elise   58        C
# 245                        Minahan, Dr. William Edward   44        Q
# 252                          Stead, Mr. William Thomas   62        S
# 262                                  Taussig, Mr. Emil   52        S
# 268      Graham, Mrs. William Thompson (Edith Junkins)   58        S
# 275                  Andrews, Miss. Kornelia Theodosia   63        S
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)   50        C
# 331                                Partner, Mr. Austen   45        S
# 339                       Blackwell, Mr. Stephen Weart   45        S
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)   60        C
# 434                          Silvey, Mr. William Baird   50        S
# 438                                  Fortune, Mr. Mark   64        S
# 449                     Peuchen, Major. Arthur Godfrey   52        S
# 453                           Goldenberg, Mr. Samuel L   49        C
# 456                          Millet, Mr. Francis Davis   65        S
# 460                                Anderson, Mr. Harry   48        S
# 462                                  Gee, Mr. Arthur H   47        S
# 487                            Kent, Mr. Edward Austin   58        C
# 492                         Molson, Mr. Harry Markland   55        S
# 496                     Eustis, Miss. Elizabeth Mussey   54        C
# 515                       Walker, Mr. William Anderson   47        S
# 523    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)   44        C
# 536                  Butt, Major. Archibald Willingham   45        S
# 544                         Douglas, Mr. Walter Donald   50        C
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...   48        C
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)   53        S
# 587                   Frolicher-Stehli, Mr. Maxmillian   60        C
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)   52        C
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")   49        C
# 625                              Sutton, Mr. Frederick   61        S
# 630               Barkworth, Mr. Algernon Henry Wilson   80        S
# 645                          Harper, Mr. Henry Sleeper   48        C
# 647                Simonius-Blumer, Col. Oberst Alfons   56        C
# 659                         Newell, Mr. Arthur Webster   58        C
# 662                         Colley, Mr. Edward Pomeroy   47        S
# 698                           Thayer, Mr. John Borland   49        C
# 712                           Taylor, Mr. Elmer Zebley   48        S
# 745                       Crosby, Capt. Edward Gifford   70        S
# 765               Hogeboom, Mrs. John C (Anna Andrews)   51        S
# 772                                  Mack, Mrs. (Mary)   57        S
# 789                           Guggenheim, Mr. Benjamin   46        C
# 796                        Leader, Dr. Alice (Farnham)   49        S
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...   52        S
# 857                             Daly, Mr. Peter Denis    51        S
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...   48        S
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)   47        S
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)   56        C

# %%
df.query("Age>=44")
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 92            93         0       1
# 96            97         0       1
# 110          111         0       1
# 124          125         0       1
# 170          171         0       1
# 174          175         0       1
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 245          246         0       1
# 252          253         0       1
# 262          263         0       1
# 268          269         1       1
# 275          276         1       1
# 299          300         1       1
# 331          332         0       1
# 339          340         0       1
# 366          367         1       1
# 434          435         0       1
# 438          439         0       1
# 449          450         1       1
# 453          454         1       1
# 456          457         0       1
# 460          461         1       1
# 462          463         0       1
# 487          488         0       1
# 492          493         0       1
# 496          497         1       1
# 515          516         0       1
# 523          524         1       1
# 536          537         0       1
# 544          545         0       1
# 556          557         1       1
# 571          572         1       1
# 587          588         1       1
# 591          592         1       1
# 599          600         1       1
# 625          626         0       1
# 630          631         1       1
# 645          646         1       1
# 647          648         1       1
# 659          660         0       1
# 662          663         0       1
# 698          699         0       1
# 712          713         1       1
# 745          746         0       1
# 765          766         1       1
# 772          773         0       2
# 789          790         0       1
# 796          797         1       1
# 820          821         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male   54      0
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female   49      1
# 54                      Ostby, Mr. Engelhart Cornelius    male   65      0
# 62                         Harris, Mr. Henry Birkhardt    male   45      1
# 92                         Chaffee, Mr. Herbert Fuller    male   46      1
# 96                           Goldschmidt, Mr. George B    male   71      0
# 110                     Porter, Mr. Walter Chamberlain    male   47      0
# 124                        White, Mr. Percival Wayland    male   54      0
# 170                          Van der hoef, Mr. Wyckoff    male   61      0
# 174                            Smith, Mr. James Clinch    male   56      0
# 177                         Isham, Miss. Ann Elizabeth  female   50      0
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  female   44      0
# 195                               Lurette, Miss. Elise  female   58      0
# 245                        Minahan, Dr. William Edward    male   44      2
# 252                          Stead, Mr. William Thomas    male   62      0
# 262                                  Taussig, Mr. Emil    male   52      1
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female   58      0
# 275                  Andrews, Miss. Kornelia Theodosia  female   63      1
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female   50      0
# 331                                Partner, Mr. Austen    male   45      0
# 339                       Blackwell, Mr. Stephen Weart    male   45      0
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female   60      1
# 434                          Silvey, Mr. William Baird    male   50      1
# 438                                  Fortune, Mr. Mark    male   64      1
# 449                     Peuchen, Major. Arthur Godfrey    male   52      0
# 453                           Goldenberg, Mr. Samuel L    male   49      1
# 456                          Millet, Mr. Francis Davis    male   65      0
# 460                                Anderson, Mr. Harry    male   48      0
# 462                                  Gee, Mr. Arthur H    male   47      0
# 487                            Kent, Mr. Edward Austin    male   58      0
# 492                         Molson, Mr. Harry Markland    male   55      0
# 496                     Eustis, Miss. Elizabeth Mussey  female   54      1
# 515                       Walker, Mr. William Anderson    male   47      0
# 523    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female   44      0
# 536                  Butt, Major. Archibald Willingham    male   45      0
# 544                         Douglas, Mr. Walter Donald    male   50      1
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female   48      1
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female   53      2
# 587                   Frolicher-Stehli, Mr. Maxmillian    male   60      1
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female   52      1
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male   49      1
# 625                              Sutton, Mr. Frederick    male   61      0
# 630               Barkworth, Mr. Algernon Henry Wilson    male   80      0
# 645                          Harper, Mr. Henry Sleeper    male   48      1
# 647                Simonius-Blumer, Col. Oberst Alfons    male   56      0
# 659                         Newell, Mr. Arthur Webster    male   58      0
# 662                         Colley, Mr. Edward Pomeroy    male   47      0
# 698                           Thayer, Mr. John Borland    male   49      1
# 712                           Taylor, Mr. Elmer Zebley    male   48      1
# 745                       Crosby, Capt. Edward Gifford    male   70      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female   51      1
# 772                                  Mack, Mrs. (Mary)  female   57      0
# 789                           Guggenheim, Mr. Benjamin    male   46      0
# 796                        Leader, Dr. Alice (Farnham)  female   49      0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female   52      1
# 857                             Daly, Mr. Peter Denis     male   51      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female   48      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female   47      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56      0
#
#      Parch       Ticket      Fare        Cabin Embarked
# 6        0        17463   51.8625          E46        S
# 11       0       113783   26.5500         C103        S
# 52       0     PC 17572   76.7292          D33        C
# 54       1       113509   61.9792          B30        C
# 62       0        36973   83.4750          C83        S
# 92       0  W.E.P. 5734   61.1750          E31        S
# 96       0     PC 17754   34.6542           A5        C
# 110      0       110465   52.0000         C110        S
# 124      1        35281   77.2875          D26        S
# 170      0       111240   33.5000          B19        S
# 174      0        17764   30.6958           A7        C
# 177      0     PC 17595   28.7125          C49        C
# 194      0     PC 17610   27.7208           B4        C
# 195      0     PC 17569  146.5208          B80        C
# 245      0        19928   90.0000          C78        Q
# 252      0       113514   26.5500          C87        S
# 262      1       110413   79.6500          E67        S
# 268      1     PC 17582  153.4625         C125        S
# 275      0        13502   77.9583           D7        S
# 299      1     PC 17558  247.5208      B58 B60        C
# 331      0       113043   28.5000         C124        S
# 339      0       113784   35.5000            T        S
# 366      0       110813   75.2500          D37        C
# 434      0        13507   55.9000          E44        S
# 438      4        19950  263.0000  C23 C25 C27        S
# 449      0       113786   30.5000         C104        S
# 453      0        17453   89.1042          C92        C
# 456      0        13509   26.5500          E38        S
# 460      0        19952   26.5500          E12        S
# 462      0       111320   38.5000          E63        S
# 487      0        11771   29.7000          B37        C
# 492      0       113787   30.5000          C30        S
# 496      0        36947   78.2667          D20        C
# 515      0        36967   34.0208          D46        S
# 523      1       111361   57.9792          B18        C
# 536      0       113050   26.5500          B38        S
# 544      0     PC 17761  106.4250          C86        C
# 556      0        11755   39.6000          A16        C
# 571      0        11769   51.4792         C101        S
# 587      1        13567   79.2000          B41        C
# 591      0        36947   78.2667          D20        C
# 599      0     PC 17485   56.9292          A20        C
# 625      0        36963   32.3208          D50        S
# 630      0        27042   30.0000          A23        S
# 645      0     PC 17572   76.7292          D33        C
# 647      0        13213   35.5000          A26        C
# 659      2        35273  113.2750          D48        C
# 662      0         5727   25.5875          E58        S
# 698      1        17421  110.8833          C68        C
# 712      0        19996   52.0000         C126        S
# 745      1    WE/P 5735   71.0000          B22        S
# 765      0        13502   77.9583          D11        S
# 772      0  S.O./P.P. 3   10.5000          E77        S
# 789      0     PC 17593   79.2000      B82 B84        C
# 796      0        17465   25.9292          D17        S
# 820      1        12749   93.5000          B69        S
# 857      0       113055   26.5500          E17        S
# 862      0        17466   25.9292          D17        S
# 871      1        11751   52.5542          D35        S
# 879      1        11767   83.1583          C50        C

# %%
df["Age"].max()
# Out:
# 80

# %%
df["Age"].min()
# Out:
# 0

# %%
df["Name"].count()
# Out:
# 183

# %%
df["Age"].mean()
# Out:
# 35.66120218579235

# %%
df["Age"].std()
# Out:
# 15.654054443652294

# %%
sns.boxplot(df["Age"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df["Age"].median()
# Out:
# 36.0

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.661202    0.464481
# std     247.052476    0.470725    0.515187   15.654054    0.644159
# min       2.000000    0.000000    1.000000    0.000000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df["Age"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.hist(df["Age"],bins=5)
# Out:
# (array([13., 61., 63., 40.,  6.]),
#  array([ 0., 16., 32., 48., 64., 80.]),
#  <BarContainer object of 5 artists>)

# %%
plt.figure(figsize=(10,10))
plt.plot(df["Age"])
plt.grid()
plt.show()

# %% [markdown]
# ### 2.3 Alineamiento de los datos a la formulación del problema

# %% [markdown]
# El primer paso para el aprendizaje automático consiste en decidir qué desea predecir, que se conoce como la etiqueta o respuesta de destino. Imagine una situación en la que desea fabricar productos, pero la decisión de fabricación de cada producto depende de su número de ventas potenciales. En este caso, es recomendable predecir cuántas veces cada producto se comprará (predecir el número de ventas). Existen varias maneras de definir este problema mediante la utilización del aprendizaje automático. Elegir cómo definir el problema depende de su caso de uso o necesidad empresarial.

# %% [markdown]
# ### 2.4 Fundamentos de análisis de datos para el aprendizaje de máquina y 2.5 Atributos y etiquetas

# %%
df.shape
# Out:
# (183, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int32
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    int32
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(1), int32(2), int64(4), object(5)
# memory usage: 21.2+ KB

# %% [markdown]
# ### 2.7 Calidad de datos

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### 2.8 Análisis exploratorio de datos y 2.9 Preparación de la data para el modelamiento

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int32
# Pclass           int64
# Name            object
# Sex             object
# Age              int32
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.661202    0.464481
# std     247.052476    0.470725    0.515187   15.654054    0.644159
# min       2.000000    0.000000    1.000000    0.000000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 6                              McCarthy, Mr. Timothy J    male   54      0
# 10                     Sandstrom, Miss. Marguerite Rut  female    4      1
# 11                            Bonnell, Miss. Elizabeth  female   58      0
# ..                                                 ...     ...  ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female   47      1
# 872                           Carlsson, Mr. Frans Olof    male   33      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 889                              Behr, Mr. Karl Howell    male   26      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
df[["Pclass", "Survived","Name"]].groupby(["Pclass","Survived"], as_index=True).count()
# Out:
#                  Name
# Pclass Survived
# 1      0           52
#        1          106
# 2      0            3
#        1           12
# 3      0            5
#        1            5

# %%
df[["Sex","Pclass","Age"]].groupby(["Sex","Pclass"]).count()
# Out:
#                Age
# Sex    Pclass
# female 1        74
#        2         9
#        3         5
# male   1        84
#        2         6
#        3         5

# %%
df1=pd.read_csv('C:\\Users\\56965\Documents\python\Inel_ML\clases\Modulo3\data\\titanic_train.csv', delimiter=",", encoding='latin-1')

# %%
df1[["Sex","Pclass","Age"]].groupby(["Sex","Pclass"]).max()
# Out:
#                 Age
# Sex    Pclass
# female 1       63.0
#        2       57.0
#        3       63.0
# male   1       80.0
#        2       70.0
#        3       74.0

# %%
df.boxplot(column="Age", by="Sex")
plt.show()

# %%
df.boxplot(column="Age", by="Sex")
plt.show()

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.148495 -0.089136  0.031649 -0.083488 -0.051454
# Survived        0.148495  1.000000 -0.034542 -0.253765  0.106346  0.023582
# Pclass         -0.089136 -0.034542  1.000000 -0.306681 -0.103592  0.047496
# Age             0.031649 -0.253765 -0.306681  1.000000 -0.155949 -0.271880
# SibSp          -0.083488  0.106346 -0.103592 -0.155949  1.000000  0.255346
# Parch          -0.051454  0.023582  0.047496 -0.271880  0.255346  1.000000
# Fare            0.029740  0.134241 -0.315235 -0.092284  0.286433  0.389740
#
#                  Fare
# PassengerId  0.029740
# Survived     0.134241
# Pclass      -0.315235
# Age         -0.092284
# SibSp        0.286433
# Parch        0.389740
# Fare         1.000000

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f")
plt.show()

# %%
sns.catplot(x="Sex", hue="Survived", kind="count", data=df1)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        1            2         1       1
# 1        3            4         1       1
# 2        6            7         0       1
# 3       10           11         1       3
# 4       11           12         1       1
# ..     ...          ...       ...     ...
# 178    871          872         1       1
# 179    872          873         0       1
# 180    879          880         1       1
# 181    887          888         1       1
# 182    889          890         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 2                              McCarthy, Mr. Timothy J    male   54      0
# 3                      Sandstrom, Miss. Marguerite Rut  female    4      1
# 4                             Bonnell, Miss. Elizabeth  female   58      0
# ..                                                 ...     ...  ...    ...
# 178   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female   47      1
# 179                           Carlsson, Mr. Frans Olof    male   33      0
# 180      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56      0
# 181                       Graham, Miss. Margaret Edith  female   19      0
# 182                              Behr, Mr. Karl Howell    male   26      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 0        0  PC 17599  71.2833          C85        C
# 1        0    113803  53.1000         C123        S
# 2        0     17463  51.8625          E46        S
# 3        1   PP 9549  16.7000           G6        S
# 4        0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 178      1     11751  52.5542          D35        S
# 179      0       695   5.0000  B51 B53 B55        S
# 180      1     11767  83.1583          C50        C
# 181      0    112053  30.0000          B42        S
# 182      0    111369  30.0000         C148        C
#
# [183 rows x 13 columns]

# %%
df.to_csv("titanic2.csv")

# %%
df.to_excel("titanic2.xlsx")

# %% [markdown]
# ### 2.10 Criterios de selección de modelos

# %% [markdown]
# <ul>
# <li>1. Rendimiento del modelo.</li>
# <li>2. Explicabilidad de los resultados.</li>
# <li>3. Complejidad del modelo.</li>
# <li>4. Tamaño del conjunto de los datos.</li>
# <li>5. Dimensionalidad. </li>
# <li>5. Tiempo de entrenamiento y costo.</li>
# <li>6. Tiempo de inferencia.</li>
# </ul>

# %% [markdown]
# ### 2.11 Criterios para la evaluación de modelos

# %% [markdown]
# <h2>Matriz de confusión</h2>
# <img src="ma_conf.png">

# %% [markdown]
# #### Exactitud
#
# La exactitud es la fracción de predicciones que el modelo clasifica correctamente.
#
# Exactitud = (VP + VN) / N
#
# Siendo N el número total de predicciones.
#
# La gran limitación es que cuando las clases a categorizar están muy desequilibradas este método resulta poco útil.
#
# #### Precisión
#
# La precisión es el ratio o porcentaje de clasificaciones correctas de nuestro modelo clasificador dentro de las predicciones positivas.
#
# Precisión = VP / (VP + FP)
#
# #### Sensibilidad
#
# La sensibilidad es la proporción de pacientes que se identificaron correctamente por tener una condición, verdadero positivo, sobre el número total de pacientes que realmente presentan esa condición.
#
# Sensibilidad = VP / (VP + FN)
#
# #### Especificidad
#
# La especificidad es la proporción de pacientes que se identificaron correctamente por no tener una condición, verdadero negativo, sobre el número total de pacientes que realmente no presentan esa condición.
#
# Especificidad = VN / (VN + FP)
